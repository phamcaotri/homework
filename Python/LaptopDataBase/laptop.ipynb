# %%
import json

# %%
"""
laptop info format:

laptop_info = {
    "laptop_id": "laptop_id",
    "laptop_name": "laptop_name",
    "screen_info": {
        "screen_size": "screen_size",
        "screen_resolution": "screen_resolution",
        "screen_width": "screen_width",
        "screen_height": "screen_height",
        "panel_type": "panel_type",
        "aspect_ratio": "aspect_ratio",
        "refresh_rate": "refresh_rate",
        "touch_capability": "touch_capability",
        "surface_finish": "surface_finish",
        "brightness": "brightness",
        "color_coverage": "color_coverage",
        "color_bit": "color_bit",
    },
    "cpu_info": {
        "cpu_brand": "cpu_brand",
        "cpu_model": "cpu_model",
        "cpu_core": "cpu_core",
        "cpu_thread": "cpu_thread",
        "cpu_base_clock": "cpu_base_clock",
        "cpu_max_clock": "cpu_max_clock",
        "cpu_cache": "cpu_cache",
        "cpu_tdp": "cpu_tdp",
    }
    "gpu1_info": {
        "gpu1_brand": "gpu1_brand",
        "gpu1_model": "gpu1_model",
        "gpu1_base_clock": "gpu1_base_clock",
        "gpu1_max_clock": "gpu1_max_clock",
        "gpu1_memory": "gpu1_memory",
        "gpu1_memory_type": "gpu1_memory_type",
        "gpu1_memory_bus": "gpu1_memory_bus",
        "gpu1_memory_speed": "gpu1_memory_speed",
        "gpu1_memory_bandwidth": "gpu1_memory_bandwidth",
        "gpu1_tdp": "gpu1_tdp",
    },
    "gpu2_info": {
        "gpu2_brand": "gpu2_brand",
        "gpu2_model": "gpu2_model",
        "gpu2_base_clock": "gpu2_base_clock",
        "gpu2_max_clock": "gpu2_max_clock",
        "gpu2_memory": "gpu2_memory",
        "gpu2_memory_type": "gpu2_memory_type",
        "gpu2_memory_bus": "gpu2_memory_bus",
        "gpu2_memory_speed": "gpu2_memory_speed",
        "gpu2_memory_bandwidth": "gpu2_memory_bandwidth",
        "gpu2_tdp": "gpu2_tdp",
    },
    "ram_info": {
        "slot": "slot",
        "ram_size": "ram_size",
        "ram_type": "ram_type",
        "ram_speed": "ram_speed",
    },
    "storage_info": {
        "storage_type": "storage_type",
        "storage_capacity": "storage_capacity",
        "storage_read_speed": "storage_read_speed",
        "storage_write_speed": "storage_write_speed",
    },
    "connectivity_info": {
        "wifi": "wifi",
        "bluetooth": "bluetooth",
        "usb": "usb",
        "video_port": "video_port",
        "audio_port": "audio_port",
        "ethernet": "ethernet",
        "webcam": "webcam",
        "keyboard_backlit": "keyboard_backlit",
        "fingerprint_reader": "fingerprint_reader",
    },
    "battery_info": {
        "battery_type": "battery_type",
        "battery_capacity": "battery_capacity",
        "battery_life": "battery_life",
    },
    "dimension_info": {
        "dimension_width": "dimension_width",
        "dimension_height": "dimension_height",
        "dimension_depth": "dimension_depth",
        "dimension_weight": "dimension_weight",
    },
    "price_info": {
        "price": "price",
        "price_date": "price_date",
    },
    "review_info": {
        "review_count": "review_count",
        "review_rating": "review_rating",
    },
    "image_url": "image_url",
}
"""

def get_laptop_info(laptop_id, laptop_name, screen_info, cpu_info, gpu1_info, gpu2_info, ram_info, storage_info, connectivity_info, battery_info, dimension_info, price_info, review_info, image_url):
    laptop_info = {
        "laptop_id": laptop_id,
        "laptop_name": laptop_name,
        "screen_info": screen_info,
        "cpu_info": cpu_info,
        "gpu1_info": gpu1_info,
        "gpu2_info": gpu2_info,
        "ram_info": ram_info,
        "storage_info": storage_info,
        "connectivity_info": connectivity_info,
        "battery_info": battery_info,
        "dimension_info": dimension_info,
        "price_info": price_info,
        "review_info": review_info,
        "image_url": image_url,
    }
    return laptop_info

def get_screen_info(screen_size, screen_resolution, screen_width, screen_height, panel_type, aspect_ratio, refresh_rate, touch_capability, surface_finish, brightness, color_coverage, color_bit):
    screen_info = {
        "screen_size": screen_size,
        "screen_resolution": screen_resolution,
        "screen_width": screen_width,
        "screen_height": screen_height,
        "panel_type": panel_type,
        "aspect_ratio": aspect_ratio,
        "refresh_rate": refresh_rate,
        "touch_capability": touch_capability,
        "surface_finish": surface_finish,
        "brightness": brightness,
        "color_coverage": color_coverage,
        "color_bit": color_bit,
    }
    return screen_info

def get_cpu_info(cpu_brand, cpu_model, cpu_core, cpu_thread, cpu_base_clock, cpu_max_clock, cpu_cache, cpu_tdp):
    cpu_info = {
        "cpu_brand": cpu_brand,
        "cpu_model": cpu_model,
        "cpu_core": cpu_core,
        "cpu_thread": cpu_thread,
        "cpu_base_clock": cpu_base_clock,
        "cpu_max_clock": cpu_max_clock,
        "cpu_cache": cpu_cache,
        "cpu_tdp": cpu_tdp,
    }
    return cpu_info

def get_gpu1_info(gpu1_brand, gpu1_model, gpu1_base_clock, gpu1_max_clock, gpu1_memory, gpu1_memory_type, gpu1_memory_bus, gpu1_memory_speed, gpu1_memory_bandwidth, gpu1_tdp):
    gpu1_info = {
        "gpu1_brand": gpu1_brand,
        "gpu1_model": gpu1_model,
        "gpu1_base_clock": gpu1_base_clock,
        "gpu1_max_clock": gpu1_max_clock,
        "gpu1_memory": gpu1_memory,
        "gpu1_memory_type": gpu1_memory_type,
        "gpu1_memory_bus": gpu1_memory_bus,
        "gpu1_memory_speed": gpu1_memory_speed,
        "gpu1_memory_bandwidth": gpu1_memory_bandwidth,
        "gpu1_tdp": gpu1_tdp,
    }
    return gpu1_info

def get_gpu2_info(gpu2_brand, gpu2_model, gpu2_base_clock, gpu2_max_clock, gpu2_memory, gpu2_memory_type, gpu2_memory_bus, gpu2_memory_speed, gpu2_memory_bandwidth, gpu2_tdp):
    gpu2_info = {
        "gpu2_brand": gpu2_brand,
        "gpu2_model": gpu2_model,
        "gpu2_base_clock": gpu2_base_clock,
        "gpu2_max_clock": gpu2_max_clock,
        "gpu2_memory": gpu2_memory,
        "gpu2_memory_type": gpu2_memory_type,
        "gpu2_memory_bus": gpu2_memory_bus,
        "gpu2_memory_speed": gpu2_memory_speed,
        "gpu2_memory_bandwidth": gpu2_memory_bandwidth,
        "gpu2_tdp": gpu2_tdp,
    }
    return gpu2_info

def get_ram_info(slot, ram_size, ram_type, ram_speed):
    ram_info = {
        "slot": slot,
        "ram_size": ram_size,
        "ram_type": ram_type,
        "ram_speed": ram_speed,
    }
    return ram_info

def get_storage_info(storage_type, storage_capacity, storage_read_speed, storage_write_speed):
    storage_info = {
        "storage_type": storage_type,
        "storage_capacity": storage_capacity,
        "storage_read_speed": storage_read_speed,
        "storage_write_speed": storage_write_speed,
    }
    return storage_info

def get_connectivity_info(wifi, bluetooth, usb, video_port, audio_port, ethernet, webcam, keyboard_backlit, fingerprint_reader):
    connectivity_info = {
        "wifi": wifi,
        "bluetooth": bluetooth,
        "usb": usb,
        "video_port": video_port,
        "audio_port": audio_port,
        "ethernet": ethernet,
        "webcam": webcam,
        "keyboard_backlit": keyboard_backlit,
        "fingerprint_reader": fingerprint_reader,
    }
    return connectivity_info

def get_battery_info(battery_type, battery_capacity, battery_life):
    battery_info = {
        "battery_type": battery_type,
        "battery_capacity": battery_capacity,
        "battery_life": battery_life,
    }
    return battery_info

def get_dimension_info(dimension_width, dimension_height, dimension_depth, dimension_weight):
    dimension_info = {
        "dimension_width": dimension_width,
        "dimension_height": dimension_height,
        "dimension_depth": dimension_depth,
        "dimension_weight": dimension_weight,
    }
    return dimension_info

def get_price_info(price, price_date):
    price_info = {
        "price": price,
        "price_date": price_date,
    }
    return price_info

def get_review_info(review_count, review_rating):
    review_info = {
        "review_count": review_count,
        "review_rating": review_rating,
    }
    return review_info

def get_image_url(image_url):
    return image_url

def get_laptop_info_from_json(laptop_info_json):
    laptop_info = json.loads(laptop_info_json)
    return laptop_info

def get_laptop_info_json(laptop_info):
    laptop_info_json = json.dumps(laptop_info)
    return laptop_info_json
