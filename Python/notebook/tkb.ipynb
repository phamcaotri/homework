# %%
import pandas as pd

# %%
file_dir = r'C:\Users\caotr\Downloads\tkb.xlsx'
df = pd.read_excel(file_dir)
df.head(20)
# Out:
#                                      Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                           NaN        NaN        NaN
# 1                                           NaN        NaN        NaN
# 2   DANH SÁCH LỚP LT HỌC KỲ 1 NĂM HỌC 2023-2024        NaN        NaN
# 3                                           NaN        NaN        NaN
# 4                                           NaN        NaN        NaN
# 5                                           NaN        NaN        NaN
# 6                                           STT      MÃ MH     MÃ LỚP
# 7                                             1      CE201  CE201.O11
# 8                                             2      CE206  CE206.O11
# 9                                             3      CE408  CE408.O11
# 10                                            4      CE412  CE412.O11
# 11                                            5      CE502  CE502.O11
# ...

# %%
# make line 6 become header
header = df[6:7].values.tolist()[0]
header
df.columns = header

# %%
tenMH = 'Hệ điều hành'
csdl = df[df['TÊN MÔN HỌC'].str.contains(tenMH) == True]
# csdl = df[(df['THỨ'].str.contains('7') == True)]

csdl.drop([ 'STT', 'MÃ MH','MÃ GIẢNG VIÊN', 'KHOÁ HỌC'], axis=1, inplace=True)

print('Number of rows: ', csdl.shape[0])
csdl.head(20)
# Out:
# Number of rows:  8
# C:\Users\caotr\AppData\Local\Temp\ipykernel_12948\1009152829.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csdl.drop([ 'STT', 'MÃ MH','MÃ GIẢNG VIÊN', 'KHOÁ HỌC'], axis=1, inplace=True)
#         MÃ LỚP   TÊN MÔN HỌC TÊN GIẢNG VIÊN SĨ SỐ TỐ TC THỰC HÀNH HTGD THỨ  \
# 517  IT007.O11  Hệ điều hành            NaN    60     3         0   LT   2
# 518  IT007.O13  Hệ điều hành            NaN    60     3         0   LT   2
# 519  IT007.O16  Hệ điều hành            NaN    60     3         0   LT   6
# 520  IT007.O18  Hệ điều hành            NaN    60     3         0   LT   6
# 525  IT007.O12  Hệ điều hành            NaN    60     3         0   LT   2
# 526  IT007.O14  Hệ điều hành            NaN    60     3         0   LT   2
# ...

# %%
tenMH = 'Kiến trúc máy tính'
csdl = df[df['TÊN MÔN HỌC'].str.contains(tenMH) == True]
# csdl = df[(df['THỨ'].str.contains('7') == True)]

csdl.drop([ 'STT', 'MÃ MH','MÃ GIẢNG VIÊN', 'KHOÁ HỌC'], axis=1, inplace=True)

print('Number of rows: ', csdl.shape[0])
csdl.head(20)
# Out:
# Number of rows:  7
# C:\Users\caotr\AppData\Local\Temp\ipykernel_12948\3210774685.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csdl.drop([ 'STT', 'MÃ MH','MÃ GIẢNG VIÊN', 'KHOÁ HỌC'], axis=1, inplace=True)
#         MÃ LỚP         TÊN MÔN HỌC TÊN GIẢNG VIÊN SĨ SỐ TỐ TC THỰC HÀNH HTGD  \
# 150  IT006.O12  Kiến trúc máy tính            NaN    60     3         0   LT
# 348  IT006.O14  Kiến trúc máy tính            NaN    60     3         0   LT
# 443  IT006.O15  Kiến trúc máy tính            NaN    60     3         0   LT
# 513  IT006.O11  Kiến trúc máy tính            NaN    60     3         0   LT
# 514  IT006.O13  Kiến trúc máy tính            NaN    60     3         0   LT
# 515  IT006.O16  Kiến trúc máy tính            NaN    60     3         0   LT
# ...

# %%
# csdl.sort_values(by=['THỨ'], inplace=True)
csdl.sort_values(by=['MÃ LỚP'], inplace=True)
csdl
# Out:
# C:\Users\caotr\AppData\Local\Temp\ipykernel_12948\977389667.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csdl.sort_values(by=['MÃ LỚP'], inplace=True)
#         MÃ LỚP         TÊN MÔN HỌC TÊN GIẢNG VIÊN SĨ SỐ TỐ TC THỰC HÀNH HTGD  \
# 513  IT006.O11  Kiến trúc máy tính            NaN    60     3         0   LT
# 150  IT006.O12  Kiến trúc máy tính            NaN    60     3         0   LT
# 514  IT006.O13  Kiến trúc máy tính            NaN    60     3         0   LT
# 348  IT006.O14  Kiến trúc máy tính            NaN    60     3         0   LT
# 443  IT006.O15  Kiến trúc máy tính            NaN    60     3         0   LT
# 515  IT006.O16  Kiến trúc máy tính            NaN    60     3         0   LT
# 516  IT006.O17  Kiến trúc máy tính            NaN    60     3         0   LT
#
# ...
