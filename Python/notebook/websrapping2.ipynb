# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from facebook_scraper import get_posts
import csv
import datetime

# %%
pageid = '445366904091458'
email = '22521525@gm.uit.edu.vn'
password = '123456781@'

posts = get_posts(pageid, pages=2, credentials=(email, password), options={"comments": True})

# %%
for post in posts:
    print(post['text'])
    comments = post['comments_full']
    print('-- comments --')
    for comment in comments:
        print(comment['comment_text'])
        print('-- replies --')
        for reply in comment['replies']:
            print(reply['comment_text'])
        print('---')
# Out:
# C:\Users\caotr\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3508: UserWarning: A low page limit (<=2) might return no results, try increasing the limit
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\caotr\AppData\Roaming\Python\Python311\site-packages\facebook_scraper\facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# 📣📣Cũng vì lí do loãng group (chủ yếu là do các kdv mới duyệt bài không nghiêm ngặt) nên những bài viết sau đây sẽ không duyệt/bị xóa (trừ những bài viết hay nhưng flop do chủ bài bị cảnh báo tài khoản) (bổ sung):
# - Quá 12h nhưng reacts dưới 50.
# - Các video được chia sẻ từ TikTok
# - Các bài viết dạng text (văn bản) và mang nội dung chúc thi tốt, chúc mừng sn, google trans...
# - Các bài có độ phân giải quá thấp.
# * Những bài viết dạng tuyển thành viên cho box chat thì phải ib qtv để xin phép, đồng thời add qtv đó vào box để theo dõi hoạt động (cho quyền qtv box thì càng tốt) từ đó nếu có gì không thích hợp qtv sẽ hành động.
# + Bài viết cần ghi đầy đủ luật box và tên qtv đã cho phép.
# + Ib Trần Tuna và Phạm Đức Trung Ngọc là tốt nhất vì onl thường xuyên.
# * Các quy tắc sẽ được tiếp tục bổ sung.
# * Các thành viên nếu gặp spam thì cứ trực tiếp report để chúng tôi xử lý.
# -
# -
# -
# -
# -
# Chúc mọi người một ngày tốt lành!
# -- comments --
# Nice
# -- replies --
# ---
# Ok
# -- replies --
# ---
# Nếu duyệt được thì duyệt dùm t cái
# T là t cay lắm r đấy
# Đăng bao nhiêu bài dell bao giờ duyệt đcm 🙂
# Chắc t out cmn khỏi gr này thôi
# -- replies --
# Mạc Đình Phong =))))))))))
# Trần Tuna cười cái cc gì kêu tk duyệt bài duyệt thì duyệt đc k duyệt được thì đi lao đầu trước oto mẹ đi
# Mạc Đình Phong vcl chửi kinh v, suspend thôi :0
# Trần Tuna tại t cay chứ sao 😔
# Mạc Đình Phong tiêu chuẩn đầy đủ thì cứ yên tâm :))
# ---
# Group này có box như group khác ko vậy tôi vào kiếm meme =}}
# -- replies --
# Quang Dương đào lại đi có mấy bài tuyển tv đấy
# Trần Tuna tôi làm gì thấy đâu
# ---
# Tin chuan khong anh
# -- replies --
# ---
# Tin juan?
# -- replies --
# ---
# hay lắm ad ơi
# -- replies --
# ---
# Ồ
# -- replies --
# ---
# Lee Tiến Cong Minh Cat Dilac
# -- replies --
# ---
# =))
# -- replies --
# ---
# Đỗ Minh Thế pliz đừng duyệt mấy bài từ tiktok nữa :)
# -- replies --
# Trần Tuna ko phải tôi🙌
# ---
# Ngọc Lỏ
# -- replies --
# ---
# Bùn
# -- replies --
# ---
# À
# -- replies --
# ---
# Lee Tiến
# -- replies --
# ---
# Everyone
# -- replies --
# ---
# Dịch Phong
# -- replies --
# ---
# Vũ Gia Bảo
# -- replies --
# ---
# @everyone Xin lỗi vì đã làm phiền nhưng mời mọi người đọc kỹ trước khi đăng bài để tránh mất thời gian cho cả qtv/kdv và người đăng. Chứ dạo này mọi người đa số đăng bài không đủ tiêu chuẩn nên bị từ chối thì đừng hỏi tại sao nhé!
# -- replies --
# Trần Tuna first
# Trần Tuna
# Trần Tuna ok a
# \
# Trần Tuna Sao vài lần tôi bình luận đều hoàn toàn bị từ chối là s hả ông toàn mấy câu bthg k vô tục
# Trần Tuna ok a
# Trần Tuna ok a
# Quang Dương đâu phải mỗi tôi duyệt đâu, còn nhiều qtv/kdv khác mà. Vào tay ông trung ngọc ổng từ chối hết :)
# Trần Tuna Vậy cứ bl bị từ chối là do mấy ông qtv hả
# Trần Tuna e vào xem chùa thôi a 🥶
# Trần Tuna avt đẹp đếy
# Lương Minh Nghĩa ban nó đi qtv
# kê bro
# Trần Tuna hmmm
# Trần Tuna ko sao ko sao
# ---
# chả ai repp bruhh
# -- replies --
# ---
# Taiizen Sosuke
# -- replies --
# ---
# Putin Đại Đế
# -- replies --
# ---
# ai bảo tôi duyệt ko nghiêm:))
# -- replies --
# Phạm Đức Trung Ngọc định ghi kdv mà bị nhầm :))) có chữ "mới" kìa
# Phạm Đức Trung Ngọc ơ thế ôg duyệt hết mấy cái bài của tôi à
# Steas Nct tui auto bấm từ chối:))
# Phạm Đức Trung Ngọc
# Steas Nct =))
# Phạm Đức Trung Ngọc
# Steas Nct thật ra là t decline :Đ
# Trần Tuna Phạm Đức Trung Ngọc thằng choá m lừa bố m
# Steas Nct :))
# ---
# 😮
# -- comments --
# Lê Thiện Văn Thiện Trần Lê Minh huhuhuhu xúc động quá
# -- replies --
# Phước Thịnh Hồ Lê cmmmm
# Lê Thiện tag lun thg Hoàng Long vô
# Phước Thịnh Hồ Lê dcmm
# ---
# Nguyen Huu HaiPhạm Bảo ômg
# -- replies --
# Bách Phan ôi tr
# Bách Phan 😔
# ---
# Bắn mạnh v
# -- replies --
# Bình Răm
# ---
# Nhật Dangg stop..
# -- replies --
# La Sv Vo Tai trg anh la may dk
# La Sv Vo Tai tyfat
# ---
# Pham Trung Hieuu au mai got
# -- replies --
# Phạm Vũ bắn chất lỏng màu trắng
# ---
# Sorry bro,mẹ ông ngon quá tôi chịu ko nổi😔
# -- replies --
# Lê Công Minh 🤨📸
# ---
# Trần Long hetcuu
# -- replies --
# Khánh Quốc ca nay nang
# ---
# Ngọc Hiếu...sad
# -- replies --
# Tạ HảiAnh omg😱😱
# ---
# Le Anh Hoangg Thanh Tuấn ô mai gót
# -- replies --
# Gia Tam ô mai gót
# ---
# Nguyễn Minh Đức dảk☠️
# -- replies --
# Nguyễn Quốc Huyy anbatocammmmm
# ---
# Khánh Nguyễn OMG :O
# -- replies --
# Khuất Mạnh Đạt nhưng mà mẹ ông nhìn nwng quá 😔😔 tôi xin lỗi
# ---
# An Nguyên OMG🥵
# -- replies --
# Bách Nguyễn ố mài gớttt 😢 🤦🥵🤭☠️
# ---
# Vc
# -- replies --
# ---
# xinloi anh 3 da ra
# -- replies --
# ---
# Nguyễn Quốc Phòng Phạm Văn Hải idol mày kìa
# -- replies --
# ---
# Tú Capybara t đã khóc vì cảm động
# -- replies --
# ---
# Deo
# -- replies --
# ---
# Thành Vũ oh my god
# -- replies --
# ---
# Vinh Wibu wtf?
# -- replies --
# Quốc Khánh kệ mẹ mày :))
# Vinh Wibu và vinh vẫn xóc tiếp
# ---
# Trần Tùng omg
# -- replies --
# ---
# Du Bít Hùng Chơi omg
# -- replies --
# ---
# Bài viết này gây ra nhiều nghi vấn và hoang mang :))
# -- replies --
# ---
# Nguyn Km vô coi nè
# -- replies --
# ---
# Phát Vũ ô mai gót
# -- replies --
# Nguyễn Huy cc
# ---
# Luân Hoàng súk động
# -- replies --
# ---
# Ô mai gớt😱
# -- replies --
# ---
# Dĩ An vào suy ngẫm
# -- replies --
# ---
# Hùng Hậu omng
# -- replies --
# ---
# Trần Tài sàd
# -- replies --
# ---
# Hoàng Tuấn Trung Dương âu mai gót
# -- replies --
# Nguyễn Duy
# ---
# Dương Quân omg:))
# -- replies --
# Nguyễn Bá Hiệp nào
# ---
# Ô mai gott
# -- replies --
# ---
# Cudiez MCC oh mai gót
# -- replies --
# ---
# Ô mài gót, xin lỗi bro nhé nhưng...
# -- replies --
# ---
# Ôh mai gót 😕
# -- replies --
# ---
# Omg
# -- replies --
# ---
# Ni Sadboyy ô mai gót
# -- replies --
# ---
# ☠️☠️☠️bro????whyy
# -- replies --
# ---
# Thanh Tân Cứ Gọi Là Tài tội đồ
# -- replies --
# ---
# clm bắn caoo dị Minh Nhựt
# -- replies --
# ---
# Ok
# -- replies --
# ---
# La Gia Hưng omg omg
# -- replies --
# ---
# Nguyễn Trương Thanh Nhàn Nhật Dangg nhìn như tý fat
# -- replies --
# ---
# Như Dz âu mai gót
# -- replies --
# Đức Ninh mô Phật 🥹
# Như Dz hết cứu
# ---
# Ai ô sì mà
# -- replies --
# ---
# Vừa ra thì thấy cmt omg
# -- replies --
# ---
# Giỡn quài ní:))))))
# -- replies --
# ---
# Nguyễn Thịnh ngưng
# -- replies --
# ---
# Giaa Lâmmm :0 ô mai côt
# -- replies --
# ---
# Ănbatôcơm
# -- replies --
# ---
# Tạ Mim Quân omg OGC
# -- replies --
# ---
# Thế thg bạn diễn là bố mới của nó
# -- replies --
# ---
# Lạm dụng =((
# -- replies --
# ---
# Nguyen Quang Truongg bantumlum
# -- replies --
# ---
# Trịnh Lượngnh
# -- replies --
# ---
# mẹ đường 🐧🐧
# -- replies --
# ---
# Sad
# -- replies --
# ---
# ANH 3 Sad
# -- replies --
# ---
# t muốn coi😈
# -- replies --
# ---
# ÕMG
# -- replies --
# ---
# Ai mai got
# -- replies --
# ---
# omg
# -- replies --
# ---
# T khá bất ngờ đấy:))
# -- replies --
# ---
# Trần Hiến Bắn tung tóe
# -- replies --
# Đào ThếDũngg
# ---
# Quang Thịnh Oh my god
# -- replies --
# ---
# ăn ba tô kum
# -- replies --
# ---
# Tìm người viết văn theo mẫu sẵn.
# Có thể làm trên đt hay laptop đều được.
# Lương trả theo bài.
# Không giới hạn độ tuổi.
# -- replies --
# ---
# BO MAY MUN DU ME MAY
# -- replies --
# ---
# Tran Minh Duc o mai got
# -- replies --
# Le Huu Hien sad
# ---
# Bro..
# -- replies --
# ---
# Nguyễn Hoài An bủn
# -- replies --
# Hoàng Kha anbatocom
# ---
# Buồn 😢
# -- replies --
# ---
# Vũ Hoàng Phúc ăn ba tô cơm
# -- replies --
# ---
# Xin tên nhạc ní
# -- replies --
# ---
# Từ từ đã ta xó thắc mắc
# -- replies --
# ---
# oh my god:((
# -- replies --
# ---
# Wtf mẹ ông đó làm như thế mà ông đó không đi hỏi sự thật sao tôi nhận ra loạn lân là vô cùng vô cùng tồi tệ với ngoại tình vcl không tin được
# -- replies --
# It's sin't funny
# ---
# Thiện Đá ô mai gót
# -- replies --
# 明库 quác thờ phắc:)))
# ---
# KỆ MẸ MÀY
# -- replies --
# ---
# Được thôi bro, tôi sẽ vừa xem vừa ăn bunda rahma
# -- replies --
# ---
# xin loi nhưng tôi bắn rồi
# -- replies --
# Dũng Vinamilk ah ba to cơm
# ---
# Nguyễn Hồ Anh Minh âu mài gót
# -- replies --
# Bình Văn ớ ớ ớ mài góttttt
# ---
# Kệ mẹ mày
# -- replies --
# ---
# Minh Khang Trịnh
# -- replies --
# ---
# Gia Bảo
# -- replies --
# ---
# みかずき はちがつ 😲
# -- replies --
# Mạnh Hùng
# ---
# Nhi Phan
# -- replies --
# Thành Nông
# ---
# Nguyễn Nam :))))
# -- replies --
# ---
# =))?
# -- replies --
# ---
# Đạt Lê
# -- replies --
# ---
# Phạm Trung Kiên
# -- replies --
# ---
# Nguyễn Nghĩa
# -- replies --
# ---
# Nguyễn Tuan Anh ?
# -- replies --
# ---
# Đức Nguyễn
# -- replies --
# ---
# Đăng Vinh
# -- replies --
# ---
# Trần Huy
# -- replies --
# Trần Huy xin video bro
# ---
# Khải Minh
# -- replies --
# ---
# Thiên Hùng Công Nguyên:))))
# -- replies --
# Mạnh Vũ Văn omg:)
# ---
# Lân Gút-Boi
# -- replies --
# ---
# :))
# -- replies --
# ---
# Vũ Đình Phú
# -- replies --
# Vũ Đình Phú
# ---
# Kiên Cường
# -- replies --
# ---
# Quách Đại Sang Anh Tuan
# -- replies --
# Trần Thành =))
# ---
# Tiến PhátTuấn Kiệt:))
# -- replies --
# ---
# Nguyễn Ngọc
# -- replies --
# ---
# Bảo Châm
# -- replies --
# ---
# Ng Mai Chi
# -- replies --
# ---
# Nguyễn Phước
# -- replies --
# ---
# Lê Đình Hoàng
# -- replies --
# ---
# Vy Định ??
# -- replies --
# ---
# Nguyễn Duy Khánh
# -- replies --
# ---
# Trann Qwuan
# -- replies --
# ---
# Nguyễn Đăng Tùng
# -- replies --
# ---
# Tuấn Kha
# -- replies --
# ---
# Võ Ngọc Thạch
# -- replies --
# ---
# Lê Hải Phong
# -- replies --
# ---
# Lợi Nguyễn
# -- replies --
# ---
# Duy Khánh
# -- replies --
# ---
# Khoa Huynh Minh
# -- replies --
# ---
# Lê Huy Đạt
# -- replies --
# ---
# 😯😮😧😦
# -- replies --
# ---
# Kẻ Vô Tâm
# -- replies --
# ---
# Tuấn Lê Thành Lâm 😲
# -- replies --
# Văn Hiếu 😳 bố m gửi 2 tiếng trc k xem à
# Tuấn Lê Dell e
# ---
# Vũ Đoàn😔
# -- replies --
# ---
# Gia Minh Thành Long 😮
# -- replies --
# Bảo Huy hết cíu :))
# ---
# P.Trần Bản
# -- replies --
# ---
# Phong Trường
# -- replies --
# ---
# Minh Đức
# -- replies --
# ---
# Đức Ninh
# -- replies --
# Bui Anh Đuc chịu lặt
# ---
# Tùng Triste
# -- replies --
# ---
# Nguyễn Thị Huyền
# -- replies --
# ---
# Bành Nguyên
# -- replies --
# ---
# Vương Thành Vũ
# -- replies --
# ---
# cái ở trên là cái j v cho tôi bik hoặc cho tôi xem đc k:))?
# -- replies --
# ---
# Hattori Ryan
# -- replies --
# ---
# Quang Huy 😞
# -- replies --
# ---
# Nguyễn Xuân Long
# -- replies --
# Đỗ Nam Đức xin lỗi mẹ bạn ngon quá
# ---
# Võ Tuấn Kiệt
# -- replies --
# Huỳnh Phước Duy m tag t làm cái lon gì đmm
# Võ Tuấn Kiệt dark
# ---
# Vanh Vake
# -- replies --
# ---
# ??
# -- replies --
# ---
# Kiên Phương holly mtfk😂
# -- replies --
# Tài Tây là j;-;
# ---
# Quốc Kirito Huy
# -- replies --
# ---
# Vinh Trần
# -- replies --
# ---
# Luan Thi
# -- replies --
# ---
# Bee Bee
# -- replies --
# ---
# Trần Chí Bảo
# -- replies --
# ---
# Tuyen tv
# -- comments --
# silit
# -- replies --
# Rpt Orijjin rep ib nhe
# ---
# Xin slot
# -- replies --
# Pop Sempai rep ib
# ---
# xin slot vơi
# -- replies --
# Khoa Tran rep ib
# ---
# Xin slot ạ
# -- replies --
# Rep ib kb
# ---
# Slot với bro
# -- replies --
# Hậu Idol rep ib
# ---
# .
# -- replies --
# HaKhaBkb ib
# ---
# Sl
# -- replies --
# ---
# Xin slot
# -- replies --
# Dang Minh rep ib
# ---
# nhóm gdtg à💀
# -- replies --
# Meme ma og ii
# Võ Hẹo tên bri uy tin qa🐧
# Hàoo Lúy j ba :0
# ---
# Deptraiz vào đx ko?
# -- replies --
# Hoàii Ânn ai cho m dép hon t :))
# Hoàii Ânn rep ib
# Hoàii Ânn kb
# Võ Hẹo r
# Hoàii Ânn nt ko dc đe t them m vô.
# Võ Hẹo moẹ ảo thật đấy
# ---
# 🗿🗿
# -- comments --
# C.um
# -- replies --
# ---
# Yêu là yêu chứ iu là con cak gì
# -- replies --
# ---
# C-um
# -- replies --
# ---
# Lê Huy Đạt
# -- replies --
# ---
# 🗿
# -- replies --
# ---
# Suki Mahiro
# -- replies --
# ---
# Minh Khang Trịnh
# -- replies --
# ---
# an3tokum
# -- replies --
# ---
# Tua đến 1p26 và tận hưởng
# Tháng năm-DIO AI COVER
# Cre: khangisreal
# -- comments --
# làm quả full the play đi bro
# -- replies --
# ---
# Xin mấy ảnh meme khịa
# -- comments --
# Nguyễn Linh
# -- replies --
# ---
# Tuấn Tú
# -- replies --
# ---
# Châu Minh Châu Minh
# -- replies --
# ---
# Hữu Thanh
# -- replies --
# ---
# Hiếu Vũ
# -- replies --
# ---
# Hoàng Đạt
# -- replies --
# ---
# Đưa hết số meme trong máy ra đây
# nhanh 😠
# -- comments --
# Hà Bảo
# -- replies --
# ---
# Nguyễn Quang Huy
# -- replies --
# ---
# Hoàng Nam
# -- replies --
# ---
# Tuấn Trọng
# -- replies --
# ---
# Duy Pham
# -- replies --
# ---
# Khánh Toàn
# -- replies --
# ---
# Nguyễn Hoàng Nhân
# -- replies --
# ---
# Quoc Anh Trương
# -- replies --
# ---
# An Hết Cứu
# -- replies --
# ---
# Minh Khang Trịnh
# -- replies --
# ---
# Nam Conn
# -- replies --
# ---
# Nguyễn Khánh Tùng
# -- replies --
# ---
# Minh Hiếu
# -- replies --
# ---
# Hoàng Đạt
# -- replies --
# ---
# 🙃
# -- comments --
# S cái giường khác
# -- replies --
# Hoàng T. Nguyên chấp nhận sự thật đi cả 2 là 1 mà
# ---
# Minh Nhat t thấy m cx phải thấy🙂
# -- replies --
# ---
# Tiến Nobi thâth ra là đùi của Trung Kiên
# -- replies --
# ---
# Đúng nhận sai cãi:]
# -- comments --
# Ma lon 💀
# -- replies --
# ---
# Chs j v bro?:)
# -- replies --
# ---
#
# -- comments --
# Đạo này em mê
# -- replies --
# ---
# Du tan bao
# -- replies --
# ---
# Mời các vị
# -- comments --
# Giờ ta chẳng còn chi:)))
# -- replies --
# Khang Diy thua ôg út
# Hoàng Trần Cân cả ver alime
# Hoàng Trần thua bà út
# Khang Diy thua tulen
# Hoàng Trần
# Khang Diy 10/10
# Nguyễn Ngọc Trung Nguyên xin vid với bro
# Nguyễn Bảo Lâm lên tiktok tui lấy
# Nguyễn Ngọc Trung Nguyên xin name
# Nguyễn Ngọc Trung Nguyên
# Nguyễn Bảo Lâm đây bro nhớ cre video cho tui
# Khang Diy Cái tương lai gohan mất tay và bị 2 con android đấm đúng k
# ---
# saangtran=))
# -- replies --
# Nguyển Đoàn Công Sang adu vjp:)
# Nguyển Đoàn Công Sang lắc đít đêy
# Pé Khoa FA đập đít lun r lắc🐧
# Nguyển Đoàn Công Sang cho mình xin video đi bro
# Phạm Ngọc Phú ib kèm 20k🗿🤑🤑
# Nguyển Đoàn Công Sang vcl
# ---
# Cre:tt
# -- replies --
# Trần Gia Kỳ trông kì công quá
# Viển Tran ảnh mạng
# Viển Tran làm bơ sếch mà xấu là bị hội đồng đấy :))
# Trần Gia Kỳ dc vải
# ---
# Tui nghĩ như vậy đủ cháy rồi
# -- replies --
# Nguyễn Đạt cháy như lửa chùa
# Trung Hiếu sao lại là lửa chùa phải gọi là phờ ri phai mới đúng chứ
# ---
# Dễ
# -- replies --
# ---
# Dio nhà làm:Đ
# -- replies --
# ---
# Game nào đó tui đã chơi rất lâu
# -- replies --
# Bắc Vũ Mortal Kombat
# Tran Vinh no no shadow fight 3
# Nó chính là lynx ở shadow fight 2 đấy
# ---
# Hải Sơn Bắc
# -- replies --
# Lê Hữu Minh Đạt oh sh*t blu sky
# Lê Hữu Minh Đạt blue sky
# ---
# Lam vo anh
# -- replies --
# ---
# đẹp r
# -- replies --
# Nguyễn Công Thành vip pro
# ---
# Đại ma vương 🐛
# -- replies --
# Hoàng Dũng pi co lo
# ---
# mời gì, mời thịt chó à 🐧
# -- replies --
# Hồ Ang có thịt chó à
# Kiên Real Nc ô này k phải con chó à, tai đâu
# Hồ Ang ko ý tôi là có thịt chó à tôi đến liền
# à đây, bạn đưa thêm lá mơ nhé
# Hồ Ang oke luôn bia hơi hay j
# bia hơi hà nội nha
# Hồ Ang
# ---
# Chất
# -- replies --
# ---
# thế này thôi lười làm quá :)))
# -- replies --
# Huy Hoàng lưu anhe lolll
# Huy Hoàng thầy Bạch
# ---
# Giống con mèo nhà t
# -- replies --
# Đỗ Đức ác=))
# Hình Kiệt haha
# ---
# Thanh Thuy m dk
# -- replies --
# Ng Trung Hieu kh em ạ
# Thanh Thuy droi còn ngại
# Ng Trung Hieu chú m nói thế mất quan điểm quá
# ---
# Ác wuỷ :))
# -- replies --
# ---
# Tai nó đâu
# -- replies --
# ---
# Cre: tôi đấy ae
# -- replies --
# ---
# M thả t ra đc rồi đó:)
# -- replies --
# ---
# Itachi
# -- replies --
# ---
# Adu dogemon
# -- replies --
# ---
# Hmmm theo t thì mình cần thêm lọ mắm tôm thêm vài cây sả thêm tí gia vị là hợp lí :))
# -- replies --
# Triệu Nông bé thế này chx đc đâu hồi trc t ăn r nên bt :))
# Long Hà :))
# Triệu Nông :)))
# ---
# Vừa spawn đã được mớ skin :))
# -- replies --
# ---
# Con này nhỏ quá kh no đâu🐧
# -- replies --
# ---
# Đg chờ hình black kuku
# -- replies --
# ---
# Ngon🤤
# -- replies --
# ---
# Ngon
# -- replies --
# ---
# Gộ nè
# -- replies --
# ---
# Tai đâu r
# -- replies --
# ---
# Aku sayya
# -- replies --
# ---
# Mohican
# -- replies --
# ---
# Hi
# -- replies --
# ---
# mời bạn
# -- replies --
# Cheems Vịt
# Nguyễn Đức Bắc xin vid bạn
# kk
# ---
# Hợp lí nhá
# -- replies --
# ---
# Hảo Hán Lương Sơn các tác phẩm tụ tập:)
# -- replies --
# ---
# Nguyễn Đức Tiến anh 1111111 kìa
# -- replies --
# Nguyễn Quốc Chiến mặt hơi dài :))))))
# ---
# KUJO JOTADOG!!!!
# -- replies --
# ---
# Lấy trên tt đó mấy fen
# -- replies --
# ---
# giềng
# -- replies --
# ---
# Gust
# -- replies --
# ---
# Mới thấy trên tiktok
# -- replies --
# ---
# Tấn Thành nhìn bl:)
# -- replies --
# Đinh Công Triệu Tr ơi tr 🗿 Mấy thk khứa này bl
# ---
# Hơn 100 skin r💀
# -- replies --
# ---
# Ggg
# -- replies --
# ---
# Trần Kiên quá khứ
# -- replies --
# ---
# Đáng yêu quá =))
# -- replies --
# ---
# Khanhh Ly lướt cmt
# -- replies --
# ---
# thiếu lá mơ r
# -- replies --
# ---
# cringe
# -- replies --
# ---
# adu ăng seng
# -- replies --
# ---
# Cháy
# -- replies --
# ---
# Vũ Hoàng Dương làm meme :))
# -- replies --
# Anh Luu tai nó đâu 🙂
# Vũ Hoàng Dương ko bt nx :)
# Anh Luu 😳😳😳
# Vũ Hoàng Dương :V
# No 2 mũi r 🙂
# Vũ Hoàng Dương ghép lệch :)
# Vũ Hoàng Dương
# Anh Luu quên xoá cái mũo đen dưới 🙂
# Vũ Hoàng Dương ghép quần áo vào nó :))
# ---
# Xiên chetme m giờ
# -- replies --
# ---
# Giá
# -- replies --
# ---
# Bonus mắm tôm
# -- replies --
# ---
# Sendo
# -- replies --
# ---
# tai đâu ?:))
# -- replies --
# ---
# Rô bờ nóc
# -- replies --
# ---
# T vẽ skin róc lóc t
# -- replies --
# ---
# Siuuuuuuuu
# -- replies --
# ---
# avt t :))
# -- replies --
# ---
# Gecko
# -- replies --
# ---
# I found this on Facebook �
# -- replies --
# ---
# Ko bt vẽ tóc
# -- replies --
# ---
# ae còn này hả???
# -- replies --
# ---
# Simon "Daug" Riley
# -- replies --
# ---
# Nguyễn Sơn
# -- replies --
# Nguyễn Sơn :))
# Nguyễn Sơn nể phục ní luôn
# pikachu dethw
# ---
# Toàn các hảo thủ 🤣🤣🤣
# -- replies --
# ---
# Nhìn nó hình như thèm mắm tôm
# -- replies --
# ---
# Thấy ae toàn lấy ảnh chỗ khác nhỉ=))
# -- replies --
# ---
# 10 đỉm
# -- replies --
# ---
# Thanh Triệu
# -- replies --
# ---
# Toàn mấy thánh lưu trên mạng
# -- replies --
# ---
# Cre tt
# -- replies --
# ---
# Fan Huy
# -- replies --
# ---
# Phùng Hưng
# -- replies --
# Phùng Hưng vãi :)))
# Thiên Trọng thì tui lụm đc tren top top ma
# ---
# Đức Võ
# -- replies --
# ---
# :))
# -- replies --
# ---
# Victus Truong
# -- replies --
# Victus Truong đầu tư dữ 3
# ---
# Nguyễn Đăng
# -- replies --
# ---
# Hoàng Lộc
# -- replies --
# ---
# Hoàng Lộc
# -- replies --
# ---
# Thiên Quang Vũ
# -- replies --
# ---
# =))))
# -- replies --
# ---
# Tống Ngọc Hải Âu
# -- replies --
# ---
# Tống Ngọc Hải Âu
# -- replies --
# ---
# Quốc Tuấn
# -- replies --
# ---
# Cường Trâu Đại Dương
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Đặng Nhật Vỹ
# -- replies --
# ---
# Narancia Ghirga
# -- replies --
# ---
# Thế Sơnn
# -- replies --
# Trường Phúcc
# ---
# Ha Phuongg
# -- replies --
# ---
# Nguyễn Caolễ
# -- replies --
# ---
# Phạm Duy Anh
# -- replies --
# ---
# Ng Thanh Duong
# -- replies --
# ---
# Nguyên Hoàng Khang
# -- replies --
# Nguyên Hoàng Khang clm tự nhiên thấy buồn cười xong xem lại thấy nó nhạt vc ;-;
# ---
# Đỗ Gia Huy
# -- replies --
# Đỗ Gia Huy sao lại ăn cắp
# ---
# Nguyễn Tiến
# -- replies --
# Nguyễn Tiến Dữ dằn
# ---
# Lê Nhân
# -- replies --
# ---
# Trần Thị Kim Thoa
# -- replies --
# ---
# Nguyễn Minh Khang
# -- replies --
# ---
# Bốp Bốp
# -- replies --
# Tàn Sát Bắc Kì vẫn thua ông út :))
# ---
# Nguyễn Văn Kỳ
# -- replies --
# ---
# Tuan Nguyễn
# -- replies --
# Tuan Nguyễn
# ---
# Nhật Nam
# -- replies --
# ---
# Cuong Nguyen
# -- replies --
# ---
# Gia Bao
# -- replies --
# Gia Bao riel ?
# Gia Bao ESCAPE FROM TAKOV ĐI NÍ🤑🤑🤑
# ---
# Tui có full 😃
# -- replies --
# ---
# V Chí Thành
# -- replies --
# ---
# Nguyễn Ngọc Vũ
# -- replies --
# ---
# Tấn Nguyễn
# -- replies --
# ---
# Nhiên Lê
# -- replies --
# ---
# Nguyễn Hải Đăng
# -- replies --
# ---
# Vũ Thành Đại
# -- replies --
# ---
# Kha Nguyễn
# -- replies --
# Kha Nguyễn thua luôn
# ---
# Gia Huy
# -- replies --
# ---
# Nguyễn Mạnh Tuấn
# -- replies --
# ---
# Richard Pham
# -- replies --
# Richard Pham nhìn sang quá
# ---
# Hoàng Nam
# -- replies --
# ---
# Beoquaman Theanh
# -- replies --
# ---
# Hân Ngô
# -- replies --
# ---
# Mạnh Dũng
# -- replies --
# ---
# Nguyễn Thịnh
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Dũng Phùng
# -- replies --
# ---
# Nguyễn Đức Huy
# -- replies --
# ---
# Nam Bị Sập Nguồn
# -- replies --
# ---
# Marzk Nguyễn
# -- replies --
# ---
# Phạm Gia Phong
# -- replies --
# Phạm Gia Phong :)))) ngài bạch
# ---
# =))
# -- replies --
# ---
# Phương Anh
# -- replies --
# ---
# Nhìn Cốn Lài
# -- replies --
# ---
# Phát Nguyễn
# -- replies --
# ---
# Lê Khương
# -- replies --
# ---
# Phạm Lonq
# -- replies --
# ---
# Quốc Danh
# -- replies --
# Quốc Danh pháo cek=)
# ---
# Dương Văn Tiến
# -- replies --
# ---
# ロク ッ
# -- replies --
# ---
# Quốc Champion
# -- replies --
# ---
# Thiện Châu
# -- replies --
# ---
# Bạn Đức Không Tên
# -- replies --
# Bạn Đức Không Tên xin vid
# Nguyễn Thế Đại ib
# ---
# Việt　　　　　 Hương
# -- replies --
# ---
# :))
# -- replies --
# ---
# Lê Văn Thuận
# -- replies --
# ---
# Gia Huy
# -- replies --
# ---
# Ngô Quốc Đạt
# -- replies --
# ---
# 🐧🐧
# -- replies --
# ---
# Huỳnh Long
# -- replies --
# ---
# Cu Quang
# -- replies --
# ---
# Thịnk Thần Đằng
# -- replies --
# ---
# Nguyễn Thiên
# -- replies --
# ---
# Phan Thị Thúy Anh
# -- replies --
# ---
# Trà Trí
# -- replies --
# ---
# Hoàng Vũ
# -- replies --
# ---
# Nguyen Nhat Anh
# -- replies --
# ---
# Think fast chucklenuts
# -- replies --
# ---
# p-phan ung cua tao
# -- replies --
# ---
# Trung Đức
# -- replies --
# ---
# Dương Văn Vũ
# -- replies --
# ---
# An Nguyễn
# -- replies --
# ---
# Việt Khánh
# -- replies --
# ---
# Lê Trọng Huy
# -- replies --
# Lê Trọng Huy
# Lê Trọng Huy
# ---
# Nhân
# -- replies --
# ---
# Đăng Lê
# -- replies --
# ---
# Đặc Cầu
# -- replies --
# ---
# Fam Kel
# -- replies --
# ---
# Name của chiếc meme này là gì vậy ae ?
# -- replies --
# ---
# Cái meme tên gì vậy ông
# -- replies --
# ---
# Bủh Bủh Dẳk Dẳk
# -- replies --
# ---
# Phi Long
# -- replies --
# ---
# An Đỗ
# -- replies --
# ---
# Hoangf Long
# -- replies --
# ---
# Minh Lợi
# -- replies --
# ---
# Còn bao Nhiêu?
#
# How Many More?
# -- comments --
# đã chết
# -- replies --
# ---
# Deo co
# -- replies --
# ---
# deo cs ai
# -- replies --
# ---
# Deo co
# -- replies --
# ---
# Deo co
# -- replies --
# ---
# đéo có ai cả
# -- replies --
# ---
# Bt đâu cả nhóm từ trần hết r sao
# -- replies --
# ---
# Tao khi làm thợ điện:
# -- comments --
# Tuan Dinh sửa quạt đi em:)
# -- replies --
# Gái Điếm Già Mồm chuyên môn của t chỉ để sửa điều hòa của tàu vũ trụ thôi mấy cái quạt tuổi j
# Tuan Dinh tật
# Gái Điếm Già Mồm con lợn khuyết tật này
# ---
# Lộc Hưng coi bắt điều hoà t cho đàg hoàg
# -- replies --
# Tấn Đạt yên tâm t bắt có mà 1 hỏng 2 hư
# Lộc Hưng
# ---
# Bich Tuyenn t do
# -- replies --
# Đình Phúc gioi qua tr gioi r:))
# Bich Tuyenn :))
# ---
# Vũ Thùy Trang thợ điện
# -- replies --
# Âu Đình Tài khôn 👍
# Vũ Thùy Trang 🤣
# ---
# Sao ông đó sống hay v
# -- replies --
# Lâm Mạnh Phước trong người có totem of unddying:))
# ---
# Nguyễn Quốc Bảo mai t sửa đt cho
# -- replies --
# Trần Quốc Tuấn cc
# ---
# Tuấn Đạt Hồ Khôi GiaHưng Huỳnh Nguyễn Phúc Ng Việt Hùng Lê Tú Hieu Thanh Tấn Khang Khang Đặngg Nguyễn Hậu ráng mà học nhe các em
# -- replies --
# Đìnhh Mạnh cảm ơn cho vd rất hữu ý
# Đìnhh Mạnh Sao bằng thg Phú Hoàng đc nổ cái đùng ở môn lắp đặt mà 😂
# ---
# Nguyễn Phan Bảo Quyên chương điện dễ mò:))))
# -- replies --
# Là Minh thì cx dễ :))))
# ---
# ʚPt Bảoo Zyyɞ lý dễ mà ta
# -- replies --
# Chí Kiên dễ chet 💀
# ---
# Ông đó bất tử rồi:))
# -- replies --
# ---
# Xin ngài🤣
# -- replies --
# ---
# Tấn Đạt Lê Khải ae điện công nghiệp
# -- replies --
# ---
# Trong Hoàng đã tiếp thu kiến thức=)
# -- replies --
# ---
# Võ Duy Khangg lớp mình trong tiết hc thầy huy
# -- replies --
# ---
# Tại sao ông này vẩn còi sống ??????
# -- replies --
# ---
# Sao ổg còn sốg thế :))
# -- replies --
# ---
# Gặp điện 3pha nó thật kh thấy ngày mai
# -- replies --
# ---
# ko hỉu sao h ổng còn sống nữa:))))
# -- replies --
# ---
# Hoàng Chức nghề điện dễ mà =)))
# -- replies --
# ---
# Văn Hiếu PhạmQuang NguyễnNguyễn PhướcLe Trung Hieu tụi bay tốt nghiệp như z đk
# -- replies --
# ---
# Sống dai thành huyền thoại
# -- replies --
# ---
# Vp ThànhTrung KienThành ĐạtDuong Duc@Hà Duy Anh nghề này vui lém
# -- replies --
# ---
# Xuân Giáp bọn mk sau này
# -- replies --
# Nguyễn Huy bòm
# ---
# Vào nghề thợ điện, tôi hoá thân thành electroboom từ lúc nào không hay 💀
# -- replies --
# ---
# Phú Minhh học ngành điện belike
# -- replies --
# Gia Huy t sẽ trở thành lẻ hủy diệt ngành điện😈
# ---
# Minh Tếu =)))) hình ảnh của 7/8
# -- replies --
# ---
# Ổng sẽ thành thor
# -- replies --
# ---
# Gojo Gojo anh bạn của tôi
# -- replies --
# ---
# Nguyễn Đức Quý mần thợ điện ko em 🥴🥴
# -- replies --
# Trần Quốc Nam ko mún lm mún lm công An 😆
# Nguyễn Đức Quý rứa bựa khác đừng dù bắt tau 🤣🤣🤣
# Ok bn bắt thg đi vs bn thôi 😂
# ---
# Bùi Quang Khải adu 🗿
# -- replies --
# electric-man
# ---
# Tesla chuyển sinh à
# -- replies --
# ---
# Ngu
# -- replies --
# ---
# T tự hỏi sao ôg vẫn sống đc nhỉ
# -- replies --
# ---
# Lý do con gái sống lâu hơn con trai
# -- replies --
# ---
# Hiền Thanh t chuyển qua sửa nước ☠️
# -- replies --
# ---
# sống dai vãi :))
# -- replies --
# ---
# Có thất bại mới có tử vong
# -- replies --
# ---
# Triệu Mẫn Nhii het cuu
# -- replies --
# ---
# phát minh vĩ đại
# -- replies --
# ---
# Từ chối tử thần 🐸
# -- replies --
# ---
# trung binh sinh vien bach khoa nganh dien
# -- replies --
# ---
# Thợ đụng
# -- replies --
# ---
# Xin vd vs
# -- replies --
# ---
# Anh Kiet sửa bóng đèn cho t đi 🐧
# -- replies --
# ---
# Mình tìm người viết văn theo mẫu sẵn.
# Có thể làm trên đt hay laptop đều được.
# Lương trả theo bài.
# Bạn nào muốn làm inbox.
# -- replies --
# ---
# t vẫn thắc mắc s ổng vẫn sống đc hay thế
# -- replies --
# ---
# Còn đăng là còn sống
# -- replies --
# ---
# Phạm Gia Khang cô hà tự hào vc🐧
# -- replies --
# ---
# that bai la me thanh cong
# -- replies --
# ---
# Ko hiểu sao ông này vẫn sống đc:)
# -- replies --
# ---
# sao ổng vẫn sống v :))?
# -- replies --
# ---
# lỳ dữ ba
# -- replies --
# ---
# Tập làm anh thợ điện may mắn để đến dc bên em
# -- replies --
# ---
# Ổng còn sống ko vậy =))?
# -- replies --
# ---
# Kiều Thúy Vy Lý này cháy phết🐧
# -- replies --
# Wackson Quang Pham báo thì có
# ---
# sống đc là cả 1 kì tích r =))
# -- replies --
# ---
# Cho tao hỏi khứa này còn sống ko
# -- replies --
# ---
# Lí do đàng ông chết sớm
# -- replies --
# ---
# Nam Kim từ chối tử thần
# -- replies --
# Nguyễn Đức anh thợ điện may mắn
# ---
# Nguyễn Thiện
# -- replies --
# Thich Em êi nó chs giống t kìa
# Nguyễn Thiện chứ cc j nữa
# Thich Em hehehe thua
# ---
# Ph Vy
# -- replies --
# ---
# Nguyễn Hữu Trọng
# -- replies --
# ---
# Tạ Quang Tú💀
# -- replies --
# ---
# Thanh Tùng
# -- replies --
# ---
# Gia Bảo
# -- replies --
# Huỳnh An mô phật
# ---
# Đỗ Hữu Thắng
# -- replies --
# Nguyễn Văn Vũ thánh sinh tồn
# ---
# Khanhh Ly
# -- replies --
# ---
# Thich Em
# -- replies --
# Bùi Phương cc j
# ---
# Lê Trọng Hiền
# -- replies --
# ---
# :))
# -- replies --
# ---
# Van Tran
# -- replies --
# Bùi Phương tương lai m đấy cu=))
# thôi cu ạ
# ---
# Hạnhh Nguyênn
# -- replies --
# Sườn Xào Chua Ngọt
# Chính là mày
# Hạnhh Nguyênn mày ấy
# ---
# Bùi Quang Đại
# -- replies --
# ---
# Nguyễn Duy Khiêm 👍
# -- replies --
# ---
# Đỗ Đình Hiếu
# -- replies --
# Đỗ Đình Hiếu xin tên kênh
# ---
# Việt Đức 💀
# -- replies --
# ---
# Dume bơm điện cho tụ nổ bỏ mẹ m
# -- replies --
# ---
# Xem Ngay Video Em Sinh Viên Thủ Dâm Lên Đỉnh Ra Nước Tung Tóe 🤓🎉🍎
# -- replies --
# ---
# Minh Quang Phạm
# -- replies --
# ---
# Tri Nguyễn
# -- replies --
# Hiei Do hong tay
# Tri Nguyễn xang sửa hộ cái quạt
# Hiei Do theo cân à
# ---
# ..
# -- comments --
# t đã đạt đc 1,1k tt =))
# -- replies --
# OnionLove Magnes đâu
# Cà Tím Lóng Tính nhưng ở gr khác=))
# OnionLove Magnes 1₫ cust ve cho
# OnionLove Magnes t dc 1.6k
# Nguyễn Khánh Duy
# ---
# Cảm giác viết bình luận được 100 tương tác
# -- replies --
# Đức Thịnh cố lên còn 99 tt thôi
# ---
# đừng ai lai bài viet cua thg nay
# -- replies --
# ---
# 1k3
# -- replies --
# ---
# ae im cho no flop di
# -- replies --
# ---
# dc 100 like toi tro thanh noledaden
# -- replies --
# ---
# Ng nổi tiếng
# -- replies --
# ---
# *xin phép ad đẹp trai
# Vào gr ủng hộ tui nha :3 https://
# www.facebook.com
# /groups/
# 690266059050526
# -- replies --
# ---
# Ad đ duyệt bài😁😁
# -- replies --
# ---
# Hiếu Vũ
# -- replies --
# ---
# AN THẦN-DIO AI COVER
# Cre: khangisreal
# -- comments --
# Bro đừng có gửi nhiều vid dio cover nx,một lần túy âm thì vui đấy nhưng nhiều lần thì ko
# -- replies --
# Tớ Tên Dũng nghe cho chill
# Tớ Tên Dũng chất giọng lồng tiếng của dio t thấy hợp với mấy bài hát mà kiểu nghe nó chill chill ý
# Tùng Hoàng chốt bài gió nhá
# Hồi đăng
# Tùng Hoàng tôi thấy đc mỗi bài túy âm nghe vừa hay vừa hài:)) còn mấy bài khác thì nghe cx bth
# Tớ Tên Dũng còn tôi thấy bài nào dio cũng hợp vì cái giọng nội lực vc=)
# ---
# Xin vid đê
# -- replies --
# Long Gà ib
# ---
# Nguyễn Xuân Thịnh dạo này dio cover vs villager cover khá nổi:)
# -- replies --
# Nguyễn Xuân Bắc :v
# ---
# Dio lạc trôi đii
# -- replies --
# ---
# Dio múa Flo 😱
# -- replies --
# ---
# thanh pahm đii
# -- replies --
# ---
# Cuốn phết
# -- replies --
# ---
# Tuấn Quang dio ngọt :v
# -- replies --
# ---
# Nguyễn Dương HồngViet Anh Nguyễn chill
# -- replies --
# ---
# Bro làm bài j mà blue tayqila j ý
# -- replies --
# ---
# Dio suyyyy
# -- replies --
# ---
# Ở 1 diễn biến khác🐧
# -- replies --
# ---
# banh cuon phet
# -- replies --
# ---
# bro toi xin vid với :>
# -- replies --
# ---
# Dio múa flo
# -- replies --
# ---
# dio sadboys
# -- replies --
# ---
# còn gì Dio cover ko mang hết ra đây
# -- replies --
# ---
# Hay=)))
# -- replies --
# ---
# Phùng Bách =))
# -- replies --
# ---
# suy x2:)
# -- replies --
# ---
# Xin video
# -- replies --
# ---
# Hmm, nghe cũng chill đấy:V
# -- replies --
# ---
# Long Gà nghe chưa vs em anh chỉ là bạn thân 😂
# -- replies --
# Minh Nguyên im lặng ik :))
# Đúng lúc t đng sầu mợ nó nghe xong sầu x4 luôn :))
# Long Gà :))
# ---
# Hảo Đặng
# -- replies --
# Nguyễn Nhả
# Hảo Đặng
# ---
# Huynh Khanh
# -- replies --
# Khoa Pham ê hay nha
# Huynh Khanh lại bảo ko hay
# ---
# Minh Khôi
# -- replies --
# ---
# Long Vũ
# -- replies --
# Nguyễn Dũng đừng gửi cho t mấy cái này
# Nguyễn Dũng T ám ảnh lắm r
# Long Vũ ;))
# ---
# Phóng Phúc
# -- replies --
# ---
# Võ Ngọc Thạch
# -- replies --
# ---
# Phùng Phước
# -- replies --
# ---
# Đỗ TùngAnh
# -- replies --
# ---
# Nguyễn Ngọc Đăng=)))
# -- replies --
# ---
# Box meme ai vô ib
# -- comments --
# xin so lut
# -- replies --
# Cà Tím Lóng Tính rrp ib
# Võ Hẹo rep mình
# ---
# Chỉ vừa thôi thì vứt:))
# -- comments --
# Anna Vũũ vừa tay😋
# -- replies --
# ---
# *xin phép ad đẹp trai
# Vào gr ủng hộ tui nha :3 https://
# www.facebook.com
# /groups/
# 690266059050526
# -- replies --
# ---
# Túy âm-DIO
# Cre: khangisreal
#
# Sound Bag - DIO
# Cre: khangisreal
# -- comments --
# có full ko pro
# -- replies --
# VP TLuan full đó bro
# Châu Minh Châu Minh à tôi nhầm tí sr
# ---
# chilll~~~!!
# -- replies --
# Ng Hai MiNh m hát cx như này này
# Thái Nguyễn Nam :Đ giọng m như gái quê 18
# Ng Hai MiNh lz :Đ
# đúng quá !!
# ---
# Nguyễn Hoàng Giang hay
# -- replies --
# Trần Đức hảo
# Nguyễn Hoàng Giang nghe cuốn
# ---
# Hayden Lavender Quỳnh Sư Tỷ Joseph Starlin Đan Hướng Dương hay quá đm t táo bón luôn 👁️👄👁️
# -- replies --
# Siesta Bình ôi ko
# Siesta Bình để chạy ra mua thuốc trị táo bón
# ---
# Phạm Minh thua
# -- replies --
# Vũ Huy ko chữa nổi
# ---
# Gia Bảo
# Thế Anh
# Cuốn
# -- replies --
# Tú Chơi Điện Tử như đấm vô lỗ tai
# ---
# đmm nhạc huyền thoại của t
# -- replies --
# Hải Đăng
# ---
# Vinh Vũ chill
# -- replies --
# ---
# Minh Phan dio
# -- replies --
# ---
# Nguyễn Tiền Hay het cuu
# -- replies --
# Ske Dungx
# ---
# https://
# www.youtube.com/
# watch?v=8iL_mn1o
# gkU
# DIO hát túy âm nhx bị ho khan
# -- replies --
# ---
# mé nó rú ))
# -- replies --
# ---
# Mé quên bản gốc rồi
# -- replies --
# ---
# bay mọe nhac huyền thoại
# -- replies --
# ---
# hay
# -- replies --
# ---
# Dành cho m Tâm Nguyễn
# -- replies --
# ---
# Hay phết:)
# -- replies --
# ---
# cx hay
# -- replies --
# ---
# Hay ghê
# -- replies --
# ---
# Nguyễn Thành vocalist
# -- replies --
# ---
# Best dio cover song ?
# -- replies --
# ---
# Vũ Nhật Minh kỉ niệm 😢😢😢
# -- replies --
# ---
# cứu dc ko ta
# -- replies --
# ---
# Duy Bảo kĩ lăng gì đây
# -- replies --
# Kiyo Izumi AI cover đó e
# ---
# Cuốn vcl
# -- replies --
# ---
# Phạm Nhựt chill bro
# -- replies --
# ---
# Đau tai
# -- replies --
# Dũng Dương thằng hề 😱😱
# ---
# tha tha
# -- replies --
# ---
# Chill phết 🤣🤣
# -- replies --
# ---
# Nghe cuốn thế nhờ
# -- replies --
# ---
# Ui có cre
# -- replies --
# Tomy Czech phải cre chứ :))
# Châu Minh Châu Minh ko như người khác thôi
# ---
# Thùy Trang cuốn luôn
# -- replies --
# ---
# Hay
# -- replies --
# ---
# Tai nghe chập mạch nghe thấy cả bản gốc :)))
# -- replies --
# ---
# conmeno phee=))
# -- replies --
# ---
# nh vậy mà buồn v
# -- replies --
# ---
# Vanh
# -- replies --
# ---
# Vũ Văn Hội
# -- replies --
# Thu Hằng hay phết:))
# ---
# Sơn Điền ngh buồn phét
# -- replies --
# ---
# Mòe Aoii
# -- replies --
# ---
# Nghe gượng quá :)))
# -- replies --
# ---
# Nge Như nín thở + rặn ỉa r hát vậy
# -- replies --
# Phạm Tanh bro miêu tả giống Goku khi hoá super saiyan thế
# ---
# Manh Tunggg
# -- replies --
# ---
# Thủng màng nhĩ
# -- replies --
# ---
# Tìm người viết văn theo mẫu sẵn.
# Có thể làm trên đt hay laptop đều được.
# Lương trả theo bài.
# Không giới hạn độ tuổi.
# -- replies --
# ---
# Nhớ về nắm 2017-2018 😭😭😭
# -- replies --
# ---
# Tha t nghe hài dell chịu đc
# -- replies --
# ---
# Đỗ TùngAnhh dio
# -- replies --
# ---
# Nguyễn Trọng Bình Nguyễn Trần Tuấn Việt Red chill thế
# -- replies --
# ---
# bản gốc của t đâu
# -- replies --
# ---
# Tôi Tên Giang tuy am dio
# -- replies --
# ---
# hay
# -- replies --
# ---
# Xin vd đi bri
# -- replies --
# ---
# Châu Minh Châu Minh làm về nhạc sobin hoàng the play đi cho dio vs jotaro mỗi đứa 1 bản đi bn nghe cho quấn :D
# -- replies --
# ---
# t nghe như đấm vào lỗ tai
# -- replies --
# ---
# đấm nhau với nhạc à :))
# -- replies --
# ---
# Súc sờ động sờ quá sờ :(((
# -- replies --
# Hoàng Humorous sờ
# ---
# hay quá, nổi cả da gà
# -- replies --
# ---
# Thlnh Đầu Cầu
# -- replies --
# ---
# Long Vũ
# -- replies --
# ---
# Bùi Ngọc Hà Exe
# -- replies --
# ---
# Nguyễn. QuốcAnh :))
# -- replies --
# ---
# Phạm AnhHoàng
# -- replies --
# ---
# Đức Bình
# -- replies --
# ---
# Nguyễn Huy
# -- replies --
# ---
# Khang Nguyen
# -- replies --
# ---
# Nam Hoang
# -- replies --
# ---
# Trương Hữu Chương
# -- replies --
# ---
# Joemama Zacdada
# -- replies --
# ---
# :))
# -- replies --
# ---
# Phúc Phóng
# -- replies --
# ---
# Ng DPhú
# -- replies --
# ---
# Trương Thái Sơn
# -- replies --
# ---
# Đoàn Hung Anh
# -- replies --
# ---
# Nguyễn Duy Vũ
# -- replies --
# ---
# Gia Bảo
# -- replies --
# ---
# Minh Khải
# -- replies --
# ---
# Con Vịt Ngáo Đất
# -- replies --
# ʚTuong Vyyɞ Dio bài gì cx cover nổi💀
# ---
# Lộ Clip Em Teen Vếu To Ngồi Móc Bím Đái Luôn Trong Bếp ♥️
# -- replies --
# ---
# Phú
# -- replies --
# Phú
# ---
# Minh Nhật
# -- replies --
# ---
# Đăng Khoa
# -- replies --
# Dcm Trongcaucutithe
# e cuốn:)
# ---
# Huỳnh Ái Thiên Quốc
# -- replies --
# ---
# :)))
# -- replies --
# ---
# Bin Cao dio hát chill vãi🐧
# -- replies --
# ---
# cứu j nữa
# -- replies --
# ---
# Nguyễn Quân
# -- replies --
# ---
# Đào Ngọc Tân
# -- replies --
# ---
# Trường An Bố mày nghe m cũng thế
# -- replies --
# ---
# Rối loạn ngôn ngữ :)
# -- comments --
# Đưa vid
# -- replies --
# ---
# Xin vid:)
# -- replies --
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 for post in posts:
#       2     print(post['text'])
#       3     comments = post['comments_full']
#
# File ~\AppData\Roaming\Python\Python311\site-packages\facebook_scraper\facebook_scraper.py:1117, in FacebookScraper._generic_get_posts(self, extract_post_fn, iter_pages_fn, page_limit, options, remove_source, latest_date, max_past_limit, **kwargs)
#    1115 logger.debug("Extracting posts from page %s", i)
#    1116 for post_element in page:
# -> 1117     post = extract_post_fn(post_element, options=options, request_fn=self.get)
#    1118     if remove_source:
#    1119         post.pop('source', None)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\facebook_scraper\extractors.py:33, in extract_post(raw_post, options, request_fn, full_post_html)
#      30 def extract_post(
#      31     raw_post: RawPost, options: Options, request_fn: RequestFunction, full_post_html=None
#      32 ) -> Post:
# ---> 33     return PostExtractor(raw_post, options, request_fn, full_post_html).extract_post()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\facebook_scraper\extractors.py:193, in PostExtractor.extract_post(self)
#     191 for method in methods:
#     192     try:
# --> 193         partial_post = method()
#     194         if partial_post is None:
#     195             log_warning("Extract method %s didn't return anything", method.__name__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\facebook_scraper\extractors.py:947, in PostExtractor.extract_video_meta(self)
#     946 def extract_video_meta(self):
# --> 947     elem = self.full_post_html.find("script[type='application/ld+json']", first=True)
#     948     if not elem:
#     949         return None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\facebook_scraper\extractors.py:1351, in PostExtractor.full_post_html(self)
#    1349 logger.debug(f"Fetching {url}")
#    1350 try:
# -> 1351     response = self.request(url)
#    1352 except exceptions.NotFound as e:
#    1353     url = self.post.get('post_url').replace(FB_BASE_URL, FB_MOBILE_BASE_URL)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\facebook_scraper\facebook_scraper.py:871, in FacebookScraper.get(self, url, **kwargs)
#     869     response = self.session.post(url=url, **kwargs)
#     870 else:
# --> 871     response = self.session.get(url=url, **self.requests_kwargs, **kwargs)
#     872 DEBUG = False
#     873 if DEBUG:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:723, in <listcomp>(.0)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\ProgramData\anaconda3\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\ProgramData\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\ProgramData\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\ProgramData\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
